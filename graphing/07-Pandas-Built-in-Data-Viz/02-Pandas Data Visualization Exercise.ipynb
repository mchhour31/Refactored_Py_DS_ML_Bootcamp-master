# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
df3.plot.scatter(x='a', y='b', c='red', figsize=(12, 3), edgecolors='black', s=30)

plt.xlim(-0.2, 1.2)
plt.ylim(-0.2, 1.2)
# Out:
# (-0.2, 1.2)

# %%
fig = plt.figure(figsize=(10, 5))

df3.plot.scatter(x='a', y='b', c='red', figsize=(12,3), edgecolors='black', s=30)

plt.xlim(-0.2, 1.2)
plt.ylim(-0.2, 1.2)

plt.grid()

plt.show()

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
plt.hist(df3['a'], edgecolor='black')
# Out:
# (array([50., 56., 65., 39., 52., 47., 44., 47., 55., 45.]),
#  array([4.10330354e-04, 1.00180351e-01, 1.99950371e-01, 2.99720392e-01,
#         3.99490412e-01, 4.99260432e-01, 5.99030453e-01, 6.98800473e-01,
#         7.98570494e-01, 8.98340514e-01, 9.98110534e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
from matplotlib import style

plt.style.use('ggplot')

plt.hist(df3['a'], edgecolor='black')
# Out:
# (array([50., 56., 65., 39., 52., 47., 44., 47., 55., 45.]),
#  array([4.10330354e-04, 1.00180351e-01, 1.99950371e-01, 2.99720392e-01,
#         3.99490412e-01, 4.99260432e-01, 5.99030453e-01, 6.98800473e-01,
#         7.98570494e-01, 8.98340514e-01, 9.98110534e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3[['a', 'b']]
# Out:
#             a         b
# 0    0.336272  0.325011
# 1    0.980265  0.831835
# 2    0.480387  0.686839
# 3    0.502106  0.305142
# 4    0.856602  0.171448
# ..        ...       ...
# 495  0.528705  0.226122
# 496  0.324730  0.215201
# 497  0.118036  0.264574
# 498  0.227021  0.660209
# 499  0.466157  0.753000
#
# [500 rows x 2 columns]

# %%
fig = plt.figure()

ax = fig.add_axes([0,1, 2, 1])

ax.boxplot(df3[['a', 'b', 'c', 'd']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x184d5a25370>,
#   <matplotlib.lines.Line2D at 0x184d5a25640>,
#   <matplotlib.lines.Line2D at 0x184d5a36760>,
#   <matplotlib.lines.Line2D at 0x184d5a36a30>,
#   <matplotlib.lines.Line2D at 0x184d5a43b80>,
#   <matplotlib.lines.Line2D at 0x184d5a43e50>,
#   <matplotlib.lines.Line2D at 0x184d5a4ff70>,
#   <matplotlib.lines.Line2D at 0x184d5a5c280>],
#  'caps': [<matplotlib.lines.Line2D at 0x184d5a259d0>,
#   <matplotlib.lines.Line2D at 0x184d5a25be0>,
#   <matplotlib.lines.Line2D at 0x184d5a36d00>,
#   <matplotlib.lines.Line2D at 0x184d5a36fd0>,
#   <matplotlib.lines.Line2D at 0x184d5a4f160>,
#   <matplotlib.lines.Line2D at 0x184d5a4f430>,
#   <matplotlib.lines.Line2D at 0x184d5a5c550>,
#   <matplotlib.lines.Line2D at 0x184d5a5c820>],
#  'boxes': [<matplotlib.lines.Line2D at 0x184d5a250a0>,
#   <matplotlib.lines.Line2D at 0x184d5a36490>,
#   <matplotlib.lines.Line2D at 0x184d5a43880>,
#   <matplotlib.lines.Line2D at 0x184d5a4fca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x184d5a25eb0>,
#   <matplotlib.lines.Line2D at 0x184d5a432e0>,
#   <matplotlib.lines.Line2D at 0x184d5a4f700>,
#   <matplotlib.lines.Line2D at 0x184d5a5caf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x184d5a361c0>,
#   <matplotlib.lines.Line2D at 0x184d5a435b0>,
#   <matplotlib.lines.Line2D at 0x184d5a4f9d0>,
#   <matplotlib.lines.Line2D at 0x184d5a5cdc0>],
#  'means': []}

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
import seaborn as sns

sns.kdeplot(df3['d'], shade=True, color='blue')
# Out:
# <AxesSubplot:xlabel='d', ylabel='Density'>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
sns.kdeplot(df3['d'], linestyle='--', linewidth=3)
# Out:
# <AxesSubplot:xlabel='d', ylabel='Density'>

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
f = plt.figure(1)
df3[:31].plot(kind='area')
plt.legend(loc='upper right', )

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
f = plt.figure(figsize =(12,5))
df3[:31].plot(kind='area')
plt.legend(bbox_to_anchor=(1.18, 1.0))

# %% [markdown]
# # Great Job!
